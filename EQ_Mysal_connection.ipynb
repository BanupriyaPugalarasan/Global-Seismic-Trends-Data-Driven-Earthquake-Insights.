# %%
import pymysql
import pandas as pd

# %%
conn = pymysql.connect(
    host = "127.0.0.1",
    user = "root",
    password="Banu@2026sql"
  )

# %%
cursor = conn.cursor()

# %%
# CREATE DATABASE
cursor.execute("CREATE DATABASE EQ_dataset;")
# Out:
# 1

# %%
#READ CSV FILE
df=pd.read_csv(r"c:\Users\HP\Downloads\Cleaned_earthquake_dataset.csv")

# %%
print(df.head())
# Out:
#            id                     time                  updated  latitude  \
# 0  us6000ddi8  2021-01-31 23:20:49.923  2021-04-16 19:02:44.040  -31.7493
# 1  us6000dev6  2021-01-31 23:08:17.161  2021-04-16 19:03:47.040  -15.4902
# 2  us6000dev5  2021-01-31 22:54:19.760  2021-04-16 19:03:47.040   19.7529
# 3  us6000ddhs  2021-01-31 22:06:00.832  2021-04-16 19:02:43.040   28.1524
# 4  us6000dev4  2021-01-31 21:51:14.016  2021-04-16 19:03:46.040   71.3212
#
#    longitude  depth_km  mag magType                   place    status  ...  \
# 0   -68.9337     17.27  4.7     mwr               Argentina  reviewed  ...
# 1  -177.2052    426.71  4.1      mb             Fiji region  reviewed  ...
# 2   121.3159     46.73  4.7      mb             Philippines  reviewed  ...
# 3    57.2570     10.00  4.9      mb                    Iran  reviewed  ...
# 4    -3.7578     10.00  4.0      mb  Svalbard and Jan Mayen  reviewed  ...
#
#     dmin   rms    gap        type  year  month day day_of_week  \
# 0  0.294  0.82   42.0  earthquake  2021      1  31      Sunday
# 1  1.471  0.29   64.0  earthquake  2021      1  31      Sunday
# 2  3.057  0.69  106.0  earthquake  2021      1  31      Sunday
# 3  3.330  0.61   71.0  earthquake  2021      1  31      Sunday
# 4  6.023  0.50   65.0  earthquake  2021      1  31      Sunday
#
#   earthquake_flag mag_flag
# 0         shallow   strong
# 1            deep   strong
# 2         shallow   strong
# 3         shallow   strong
# 4         shallow   strong
#
# [5 rows x 32 columns]

# %%
print(df.shape)
# Out:
# (104441, 32)

# %%
cursor.execute("USE EQ_dataset")
# Out:
# 0

# %%
#CREATE TABLE Earthquake_data
cursor.execute("""
CREATE TABLE Earthquake_data(
    id VARCHAR(100),
    time DATETIME(3),
    updated DATETIME(3),
    latitude FLOAT,
    longitude FLOAT,
    depth_km FLOAT,
    mag FLOAT,
    magType VARCHAR(50),
    place VARCHAR(225),
    status VARCHAR(50),
    tsunami INT,
    alert VARCHAR(10),
    Felt FLOAT,
    cdi FLOAT,
    mmi FLOAT,
    sig INT,
    net VARCHAR(100),
    code VARCHAR(100),
    ids VARCHAR(225),
    sources VARCHAR(225),
    types TEXT,
    nst FLOAT,
    dmin FLOAT,
    rms FLOAT,
    gap FLOAT,
    type VARCHAR(100),
    year INT(4),
    month INT(2),
    day INT(2),
    day_of_week VARCHAR(20),
    earthquake_flag VARCHAR(20),
    mag_flag VARCHAR(20)
)
               """)
# Out:
# 0

# %%
#insert values into table
sql="""INSERT INTO earthquake_data(
    id,time,updated,latitude,longitude,depth_km,mag,magType,place,status,
    tsunami,alert,felt,cdi,mmi,sig,net,code,ids,sources,
    types,nst,dmin,rms,gap,type,year,month,day,day_of_week,
    earthquake_flag,mag_flag
    )
    VALUES (
    # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
     # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
     # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
    )
"""

# %%
for row in df.itertuples(index=False):
    cursor.execute(sql, tuple(row))

conn.commit()

# %%
cursor.execute("select * from earthquake_data;")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                   id                    time                 updated  \
# 0         us6000ddi8 2021-01-31 23:20:49.923 2021-04-16 19:02:44.040
# 1         us6000dev6 2021-01-31 23:08:17.161 2021-04-16 19:03:47.040
# 2         us6000dev5 2021-01-31 22:54:19.760 2021-04-16 19:03:47.040
# 3         us6000ddhs 2021-01-31 22:06:00.832 2021-04-16 19:02:43.040
# 4         us6000dev4 2021-01-31 21:51:14.016 2021-04-16 19:03:46.040
# ...              ...                     ...                     ...
# 104436  ak2025xpgfse 2025-12-01 01:51:06.974 2026-02-25 16:18:40.040
# 104437    us7000ret3 2025-12-01 01:41:43.796 2026-02-25 16:18:40.040
# 104438    us7000ret2 2025-12-01 01:37:57.834 2026-02-25 16:18:40.040
# 104439    us7000resz 2025-12-01 01:25:46.725 2026-02-25 16:18:40.040
# 104440    us7000resx 2025-12-01 00:48:01.683 2026-02-25 16:18:40.040
#
#         latitude  longitude  depth_km  mag magType                   place  \
# 0       -31.7493   -68.9337    17.270  4.7     mwr               Argentina
# 1       -15.4902  -177.2050   426.710  4.1      mb             Fiji region
# 2        19.7529   121.3160    46.730  4.7      mb             Philippines
# 3        28.1524    57.2570    10.000  4.9      mb                    Iran
# 4        71.3212    -3.7578    10.000  4.0      mb  Svalbard and Jan Mayen
# ...          ...        ...       ...  ...     ...                     ...
# 104436   59.1380  -150.6400    15.200  3.2      ml                  Alaska
# 104437    7.4127   127.0700    35.000  4.6      mb             Philippines
# 104438  -19.4176   -67.2761   227.844  4.1      mb                 Bolivia
# 104439   47.3283  -113.2020    30.159  3.1      ml                 Montana
# 104440   42.0602   142.5910    57.662  4.6      mb                   Japan
#
#           status  ...   dmin   rms    gap        type  year  month day  \
# 0       reviewed  ...  0.294  0.82   42.0  earthquake  2021      1  31
# 1       reviewed  ...  1.471  0.29   64.0  earthquake  2021      1  31
# 2       reviewed  ...  3.057  0.69  106.0  earthquake  2021      1  31
# 3       reviewed  ...  3.330  0.61   71.0  earthquake  2021      1  31
# 4       reviewed  ...  6.023  0.50   65.0  earthquake  2021      1  31
# ...          ...  ...    ...   ...    ...         ...   ...    ...  ..
# 104436  reviewed  ...  0.600  0.90  149.0  earthquake  2025     12   1
# 104437  reviewed  ...  1.518  1.19   96.0  earthquake  2025     12   1
# 104438  reviewed  ...  2.371  0.73   95.0  earthquake  2025     12   1
# 104439  reviewed  ...  0.293  0.53   45.0  earthquake  2025     12   1
# 104440  reviewed  ...  0.424  0.52   83.0  earthquake  2025     12   1
#
#        day_of_week earthquake_flag mag_flag
# 0           Sunday         shallow   strong
# 1           Sunday            deep   strong
# 2           Sunday         shallow   strong
# 3           Sunday         shallow   strong
# 4           Sunday         shallow   strong
# ...            ...             ...      ...
# 104436      Monday         shallow   strong
# 104437      Monday         shallow   strong
# 104438      Monday         shallow   strong
# 104439      Monday         shallow   strong
# 104440      Monday         shallow   strong
#
# [104441 rows x 32 columns]

# %% [markdown]
# Analyst Tasks

# %%
# Magnitude & Depth
#1.Top 10 strongest earthquakes(mag)
cursor.execute("""SELECT id,place,mag 
              FROM earthquake_data  
              ORDER BY mag desc limit 10;""")

data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#              id                                   place  mag
# 0    us6000qw60                       Russia Earthquake  8.8
# 1  ak0219neiszm                       Alaska Earthquake  8.2
# 2    us7000dflf                  New Zealand Earthquake  8.1
# 3    us6000f53e  2021 South Sandwich Islands Earthquake  8.1
# 4    us6000jllz       Kahramanmaras earthquake sequence  7.8
# 5    us7000qx2g                                  Russia  7.8
# 6    us7000pn9s              Burma (Myanmar) Earthquake  7.7
# 7    us6000kd0n        southeast of the Loyalty Islands  7.7
# 8    us6000dg77        southeast of the Loyalty Islands  7.7
# 9    us7000j36j                               Indonesia  7.6

# %%
#2.Top 10 deepest eqrthquakes(depth_km)
cursor.execute(""" SELECT place,mag,depth_km
              FROM earthquake_data
              ORDER BY depth_km DESC
              LIMIT 10; """ )
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                        place  mag  depth_km
# 0                    Vanuatu  4.0   681.238
# 1             Vanuatu region  4.2   675.265
# 2                Fiji region  4.2   671.043
# 3                       Fiji  4.8   669.556
# 4                       Fiji  4.0   669.460
# 5                       Fiji  4.2   667.237
# 6  south of the Fiji Islands  4.5   664.740
# 7                       Fiji  4.3   664.700
# 8                    Vanuatu  4.1   660.826
# 9  south of the Fiji Islands  7.0   660.000

# %%
#3.Shallow earthquake <50 km and mag>7.5
cursor.execute(""" SELECT place, depth_km,mag,earthquake_flag 
              FROM earthquake_data
              WHERE depth_km<50 And mag>7.5""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                                      place  depth_km  mag earthquake_flag
# 0         southeast of the Loyalty Islands    10.000  7.7         shallow
# 1                   New Zealand Earthquake    28.930  8.1         shallow
# 2                        Alaska Earthquake    35.000  8.2         shallow
# 3   2021 South Sandwich Islands Earthquake    22.790  8.1         shallow
# 4                                   Mexico    26.943  7.6         shallow
# 5        Kahramanmaras earthquake sequence    10.000  7.8         shallow
# 6         southeast of the Loyalty Islands    18.053  7.7         shallow
# 7                              Philippines    40.000  7.6         shallow
# 8                           Cayman Islands    14.326  7.6         shallow
# 9               Burma (Myanmar) Earthquake    10.000  7.7         shallow
# 10                       Russia Earthquake    35.000  8.8         shallow
# 11                                  Russia    27.000  7.8         shallow
# 12                           Drake Passage     5.639  7.6         shallow
# 13                        Japan Earthquake    40.720  7.6         shallow

# %%
#4.Average magnitude per magnitude type(magType) #5-Q skipped
cursor.execute("""SELECT magtype,AVG(mag) AS AVERAGE_MAG
               FROM earthquake_data
               GROUP BY magType""")
              
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#        magtype  AVERAGE_MAG
# 0          mwr     4.343505
# 1           mb     4.425133
# 2           md     3.447550
# 3          mww     5.373373
# 4           ml     3.274783
# 5           mw     3.938157
# 6          mwb     5.803448
# 7        mb_lg     3.208696
# 8          mwc     6.150000
# 9          mlr     3.480000
# 10         mlg     3.300000
# 11       ms_20     5.800000
# 12         mlv     3.469288
# 13  ml(texnet)     3.367442
# 14       ms_vx     4.600000
# 15         mwp     5.250000
# 16          mh     4.100000

# %%
#TIME Analysis
#6.Year with most earthquakes.
cursor.execute("""SELECT year,count(*) AS total_earthquakes
               FROM earthquake_data
               GROUP BY year
               ORDER BY total_earthquakes DESC
               Limit 1;""" )
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#    year  total_earthquakes
# 0  2025              22818

# %%
#7.Month with Highest number of earthquakes.
cursor.execute("""SELECT month, count(*) AS total_earthquakes
               FROM earthquake_data
               GROUP BY month
               ORDER BY total_earthquakes DESC
               LIMIT 1;""")

data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#    month  total_earthquakes
# 0      8               9857

# %%
#8.Day of week with most earthquakes
cursor.execute("""SELECT day_of_week, count(*) AS total_earthquakes
               FROM earthquake_data
               GROUP BY day_of_week
               ORDER BY total_earthquakes DESC
               LIMIT 1;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#   day_of_week  total_earthquakes
# 0      Friday              15100

# %%
#9.Count of earthquakes per hour of day.
cursor.execute("""SELECT hour(time) AS hour_of_day, count(*) AS total_earthquakes
               FROM earthquake_data
               GROUP BY hour_of_day
               ORDER BY total_earthquakes DESC
               LIMIT 1;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#    hour_of_day  total_earthquakes
# 0            3               4683

# %%
#10.Most active reporting network(net)
cursor.execute("""SELECT net, count(*) AS total_earthquakes
               FROM earthquake_data
               GROUP BY net
               ORDER BY total_earthquakes DESC
               LIMIT 1;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#   net  total_earthquakes
# 0  us              91604

# %%
#Casualties & Economic Loss
#11.Top 5 places with highest Casualties. #Q-12 skipped
cursor.execute("""SELECT place, Max(felt) AS highest_casualties
               FROM earthquake_data
               GROUP BY place
               ORDER BY highest_casualties DESC
               LIMIT 5;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                    place  highest_casualties
# 0  New Jersey Earthquake            184662.0
# 1              Tennessee             45934.0
# 2                     CA             42594.0
# 3                  Maine             42439.0
# 4               Oklahoma             26480.0

# %%
#13. Average economic loss by alert level
cursor.execute("""SELECT alert,Avg(mag) AS Average_eco_loss
               FROM earthquake_data
               GROUP BY alert;
               """)
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#     alert  Average_eco_loss
# 0   green          4.257316
# 1  yellow          6.016532
# 2  orange          6.304545
# 3     red          6.687500

# %%
#Event Types & Quality Metrics
#14.Count of reviewed vs automatic earthquakes(status)
cursor.execute("""SELECT status,count(*) AS Total_Earthquakes
               FROM earthquake_data
               GROUP BY status;""")

data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#       status  Total_Earthquakes
# 0   reviewed             104292
# 1  automatic                149

# %%
#15.Count by earthquake type
cursor.execute("""SELECT type,count(*) AS Total_Earthquakes
               FROM earthquake_data
               GROUP BY type;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                      type  Total_Earthquakes
# 0              earthquake             103628
# 1        mining explosion                770
# 2               ice quake                 13
# 3  experimental explosion                  3
# 4           mine collapse                  3
# 5            quarry blast                  2
# 6       volcanic eruption                 12
# 7               landslide                  4
# 8             other event                  5
# 9               explosion                  1

# %%
#16.Number of earthquakes by data type(types).#Q-17 skipped
cursor.execute("""SELECT types,count(*) AS Number_of_Earthquakes
               FROM earthquake_data
               GROUP BY types;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                                                  types  Number_of_Earthquakes
# 0                 dyfi,moment-tensor,origin,phase-data                   1268
# 1                                    origin,phase-data                  79558
# 2    dyfi,impact-text,internal-origin,losspager,mom...                      8
# 3                               dyfi,origin,phase-data                   8208
# 4                      moment-tensor,origin,phase-data                   1238
# ..                                                 ...                    ...
# 549   impact-link,losspager,origin,phase-data,shakemap                      6
# 550  dyfi,earthquake-name,finite-fault,ground-failu...                      1
# 551  dyfi,ground-failure,impact-link,losspager,orig...                      1
# 552  dyfi,earthquake-name,event-sequence,finite-fau...                      1
# 553  dyfi,event-sequence,internal-moment-tensor,mom...                      1
#
# [554 rows x 2 columns]

# %%
#18.Events with high station coverage(nst>thresold)
cursor.execute("""SELECT mag_flag,ids,mag,nst
               FROM earthquake_data
               WHERE nst>mag
               ORDER BY nst DESC;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#            mag_flag                                              ids   mag  \
# 0       destructive                        us6000m12f,usauto6000m12f  5.40
# 1            strong                        usauto6000qzfl,us6000qzfl  5.00
# 2       destructive  us7000pvtr,pt25119052,at00svhipf,usauto7000pvtr  6.80
# 3       destructive             usd001097k,usauto7000li78,pt23345002  5.50
# 4       destructive  us7000ilwt,usauto7000ilwt,pt22306000,at00rkpewo  6.00
# ...             ...                                              ...   ...
# 104243       strong                                       pr71352418  3.01
# 104244       strong                                       pr71351878  3.41
# 104245       strong                                       pr71368488  3.15
# 104246       strong                                     pr2021164003  3.05
# 104247       strong                                       ci39928368  3.31
#
#           nst
# 0       619.0
# 1       566.0
# 2       475.0
# 3       466.0
# 4       452.0
# ...       ...
# 104243    4.0
# 104244    4.0
# 104245    4.0
# 104246    4.0
# 104247    4.0
#
# [104248 rows x 4 columns]

# %%
#Tsunamis & Alerts
#19. Number of Tsunamis triggered per year
cursor.execute("""SELECT year,tsunami,count(*) AS Total_earthquakes
               FROM earthquake_data
               WHERE tsunami =1
               GROUP BY year
               ORDER BY Total_earthquakes DESC;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#    year  tsunami  Total_earthquakes
# 0  2025        1                142
# 1  2022        1                136
# 2  2023        1                119
# 3  2021        1                114
# 4  2024        1                114

# %%
#20.Count earthquakes by alert levels(red,Orange,etc)
cursor.execute("""SELECT alert,count(*) AS Total_earthquakes
               FROM earthquake_data
               GROUP BY alert
               ORDER BY Total_earthquakes DESC;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#     alert  Total_earthquakes
# 0   green             104271
# 1  yellow                124
# 2     red                 24
# 3  orange                 22

# %%
#Seismic Pattern & Trends Analysis.
#21.Find the top 5 countries with the highest average magnitude of earthquakes in the past 5 years
cursor.execute("""SELECT place,AVG(mag) AS Avarage_magnitude
               FROM earthquake_data
               GROUP BY place
               ORDER BY Avarage_magnitude DESC
               LIMIT 5;""")
               
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                                     place  Avarage_magnitude
# 0  2021 South Sandwich Islands Earthquake           8.100000
# 1                  New Zealand Earthquake           8.100000
# 2                       Russia Earthquake           8.100000
# 3              Burma (Myanmar) Earthquake           7.700000
# 4                       Alaska Earthquake           7.566667

# %%
#22.Find countries that have experienced both shallow and deep earthquakes within the same month
cursor.execute("""SELECT place
               FROM earthquake_data
               GROUP BY place, month
               HAVING SUM(earthquake_flag = "shallow")>0 AND SUM(earthquake_flag = "deep")>0;
               """)
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                               place
# 0                         Argentina
# 1                       Fiji region
# 2                       Philippines
# 3                         Indonesia
# 4                 Wallis and Futuna
# ..                              ...
# 267               Wallis and Futuna
# 268  northwest of the Kuril Islands
# 269       Santa Cruz Islands region
# 270                  Vanuatu region
# 271                     Celebes Sea
#
# [272 rows x 1 columns]

# %%
#23.Compute the year-over-year growth rate in the total number of earthquakes globally.
cursor.execute(""" SELECT
               year,
               total_earthquake,

               LAG(total_earthquake) OVER (ORDER BY year) AS prev_year_earthquake,
               ROUND(
               (
               (total_earthquake-LAG(total_earthquake) OVER (ORDER BY year))*100.0 /
               LAG(total_earthquake) OVER(ORDER BY year)
               ),
               2 ) AS yoy_growth_rate

               FROM (SELECT year,
               COUNT(*) AS total_earthquake
               FROM earthquake_data
               GROUP BY year) AS yearly;
               """
               )
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#    year  total_earthquake  prev_year_earthquake yoy_growth_rate
# 0  2021             21926                   NaN            None
# 1  2022             20208               21926.0           -7.84
# 2  2023             20830               20208.0            3.08
# 3  2024             18659               20830.0          -10.42
# 4  2025             22818               18659.0           22.29

# %%
#24.List the 3 most seismically active regions by combining both frequency and average magnitude.
cursor.execute("""SELECT place,
               COUNT(*) AS frequency,
               AVG(mag) AS Avg_magnitude
               FROM earthquake_data
               GROUP BY place;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                                place  frequency  Avg_magnitude
# 0                          Argentina       1417       4.428864
# 1                        Fiji region       1220       4.364426
# 2                        Philippines       4351       4.557136
# 3                               Iran        880       4.389318
# 4             Svalbard and Jan Mayen        110       4.502727
# ..                               ...        ...            ...
# 514           southwest of Australia          1       4.700000
# 515                      Netherlands          1       3.800000
# 516             United Arab Emirates          1       4.300000
# 517                Taiwan Earthquake          1       6.000000
# 518  2025 Hubbard Glacier Earthquake          1       7.000000
#
# [519 rows x 3 columns]

# %%
#25.For each country, calculate the average depth of earthquakes within ±5° latitude range of the equator.
cursor.execute("""SELECT place, AVG(depth_km) AS Avg_depth_km
               FROM earthquake_data
               WHERE latitude  between -5 and +5
               GROUP BY place;
               """)
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                                      place  Avg_depth_km
# 0                              Philippines    125.779801
# 1                                   Guyana     10.351429
# 2                                Indonesia     63.855400
# 3                                  Ecuador     61.281627
# 4                north of Ascension Island     10.000000
# 5                                 Colombia     39.724345
# 6                              Celebes Sea    452.787274
# 7         Democratic Republic of the Congo      9.914739
# 8                         Papua New Guinea     70.772218
# 9                                  Burundi     10.000000
# 10                             Molucca Sea     51.642222
# 11               central East Pacific Rise     10.000000
# 12                         Carlsberg Ridge     10.045306
# 13                         south of Panama     10.204000
# 14                                    Peru     65.394868
# 15              central Mid-Atlantic Ridge     10.010464
# 16        off the coast of Central America     10.316544
# 17                            Palau region     15.090000
# 18                                  Uganda     10.000000
# 19                                Tanzania     10.000000
# 20                                   Gabon      9.818182
# 21                off the coast of Ecuador     11.463533
# 22        Galapagos Triple Junction region     10.000000
# 23               Chagos Archipelago region     10.000000
# 24                      North Indian Ocean     10.000000
# 25                                  Brazil     10.556000
# 26                               Banda Sea    339.384004
# 27                                  Rwanda     10.441538
# 28           west of the Galapagos Islands     10.000000
# 29                         Kiribati region     10.000000
# 30                             South Sudan     10.000000
# 31  off the west coast of northern Sumatra     10.642857
# 32                                  Panama     10.000000
# 33                      South Indian Ocean     11.333333
# 34   Federated States of Micronesia region     10.000000
# 35                          Ecuador region     10.000000
# 36                                   Palau     10.000000
# 37                           northern Peru     55.071002
# 38                                Ethiopia     10.000000
# 39                                Malaysia     11.525000
# 40                            Bismarck Sea    106.018331
# 41              Peru-Ecuador border region     59.682999
# 42               near the coast of Ecuador     30.973000
# 43                                   Kenya      9.866000
# 44                            Congo-Uganda     14.775000
# 45              east central Pacific Ocean     10.000000
# 46          Colombia-Ecuador border region     10.000000
# 47                               Venezuela     11.127000
# 48                    South Atlantic Ocean     10.000000

# %%
#26.Identify countries having the highest ratio of shallow to deep earthquakes.
cursor.execute("""SELECT place,
               SUM(earthquake_flag = "shallow") AS shallow_count,
               SUM(earthquake_flag = "deep") AS deep_count,
               SUM(earthquake_flag = "shallow") *1.0 /NULLIF(SUM(earthquake_flag ="deep"),0) AS ratio
               FROM earthquake_data
               GROUP BY place
               ORDER BY ratio DESC;""")               
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                                place shallow_count deep_count       ratio
# 0                              China          1262          1  1262.00000
# 1                               Peru          1249          1  1249.00000
# 2                        Afghanistan           934          1   934.00000
# 3                               Guam           744          1   744.00000
# 4                        New Zealand          1598         10   159.80000
# ..                               ...           ...        ...         ...
# 514           southwest of Australia             1          0        None
# 515                      Netherlands             1          0        None
# 516             United Arab Emirates             1          0        None
# 517                Taiwan Earthquake             1          0        None
# 518  2025 Hubbard Glacier Earthquake             1          0        None
#
# [519 rows x 4 columns]

# %%
#27.Find the average magnitude difference between earthquakes with tsunami alerts and those without.
cursor.execute("""SELECT
               AVG(CASE WHEN tsunami = 1 then mag END) -
               AVG(CASE WHEN tsunami = 0 THEN mag END) AS avg_magnitude_difference
               FROM earthquake_data;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#    avg_magnitude_difference
# 0                  1.163851

# %%
#28.Using the gap and rms columns, identify events with the lowest data reliability (highest average error margins). #Q29 skipped
cursor.execute("""SELECT id,
               place,
               gap,
               rms
               FROM earthquake_data
               ORDER BY gap DESC,rms DESC
               LIMIT 1 ;
               """)
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#            id   place     gap     rms
# 0  nn00897599  Nevada  358.18  0.1601

# %%
#30.Determine the regions with the highest frequency of deep-focus earthquakes (depth > 300 km).
cursor.execute("""SELECT place,count(*) AS frequency
               FROM earthquake_data
               WHERE depth_km>300
               GROUP BY place
               ORDER BY frequency DESC
               LIMIT 1;""")
data = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df=pd.DataFrame(data, columns=columns)
print(df)
# Out:
#                        place  frequency
# 0  south of the Fiji Islands       1529
